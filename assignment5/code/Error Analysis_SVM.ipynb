# %%
import os
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, recall_score, precision_score
# os.chdir(os.getcwd()[:-5])
warnings.filterwarnings("ignore")

# %%
svm_test = pd.read_csv('resuts/SVM_test_result.csv')

# %%
class Format:
    end = '\033[0m'
    underline = '\033[4m'
    bold = '\033[1m'

def classify_predictions(row, pred_column):
    
    if row[pred_column] == row['Negation_cue']:
        
        if row[pred_column] == 'O':
            return 'TN'
        return 'TP'
    
    if row[pred_column] in ['B-NEG', 'I-NEG']:
        return 'FP'
    
    return 'FN'

def construct_sentence(df, pred_column):
    sentence = ''
    df = df.reset_index(drop=True)
    for i, token in enumerate(df.Token):
        
        error_type = df.loc[i, 'class']
        
        if error_type == 'FN':
            sentence += ' ' + Format.bold + token + Format.end
        elif error_type == 'FP':
            sentence += ' ' + Format.underline + token + Format.end
        elif error_type == 'TP':
            sentence += ' ' + Format.bold + Format.underline + token + Format.end
        else:
            if token in ['.', ',', '?', '!']:
                sentence += token
            else:
                sentence += f' {token}'
    
    return sentence[1:]

def print_error(df, error, pred_column):
    
    error = df[df['class'] == error]
    error_trigram = error.trigram.values[0]
    print('Error:', Format.underline, error_trigram, Format.end, '\t',
         f'Predicted: {error[pred_column].values[0]}; Actual: {error.Negation_cue.values[0]}')
    
    sentence = construct_sentence(df, pred_column)
    print(sentence, '\n')
    
def print_errors(df, pred_column):
    
    df['class'] = df.apply(classify_predictions, args=(pred_column,), axis=1)
    
    FP_sentences = df[df['class'] == 'FP'].idx_sent.values
    FN_sentences = df[df['class'] == 'FN'].idx_sent.values
    
    print('F1-score:  ', Format.bold, round(f1_score(df.Negation_cue, df[pred_column], average='weighted', zero_division=0),4), Format.end)
    print('Precision: ', Format.bold, round(precision_score(df.Negation_cue, df[pred_column], average='weighted'),4), Format.end)
    print('Recall:    ', Format.bold, round(recall_score(df.Negation_cue, df[pred_column], average='weighted'),4), Format.end, '\n')
    
    print('Number of False Positives:', Format.bold, len(FP_sentences), Format.end)
    print('Number of False Negatives:', Format.bold, len(FN_sentences), Format.end, '\n\n')
    
    print(Format.bold + 'False Positives' + Format.end, '\n')
    for sentence_id in FP_sentences:
        print_error(df[df.idx_sent == sentence_id], 'FP', pred_column)
    
    print('\n\n', Format.bold + 'False Negatives' + Format.end, '\n')
    for sentence_id in FN_sentences:
        print_error(df[df.idx_sent == sentence_id], 'FN', pred_column)

def print_confusion_matrix(prediction, actual):
    confusion_matrix = pd.crosstab(actual, prediction, rownames=['Actual'], colnames=['Predicted'])
    sns.heatmap(confusion_matrix, annot=True)
    plt.suptitle('Confusion matrix')
    plt.show()

def error_analysis(df, pred_column):
    
    print('\t\t', Format.bold, 'ERROR ANALYSIS', Format.end, '\n\n')
    print_confusion_matrix(df[pred_column], df.Negation_cue)
    print_errors(df, pred_column)

# %%
error_analysis(svm_test, 'pred_SVM')
# Out:
# 		  ERROR ANALYSIS
# F1-score:    0.9962
# Precision:   0.9961
# Recall:      0.9964
#
# Number of False Positives:  35
# Number of False Negatives:  35
#
#
# False Positives
#
# Error:  , no doubt  	 Predicted: B-NEG; Actual: O
# You have also, no doubt, remarked that Miss Cushing has cut the cord with a scissors, as can be seen by the double fray on each side. " Well, I think we must wait for a little more material.
#
# Error:  with nothing distinctive  	 Predicted: B-NEG; Actual: O
# The box is a yellow, half-pound honeydew box, with nothing distinctive save two thumb marks at the left bottom corner. I can imagine that the word was taken out of a dictionary, which would give the noun but not the plural.
#
# Error:  , no doubt  	 Predicted: B-NEG; Actual: O
# " There are objections to the joke theory, no doubt, " said he, " but there are much stronger reasons against the other. " Be patient.
#
# Error:  do n't know  	 Predicted: B-NEG; Actual: O
# " Ah! you do n't know Sarah 's temper or you would wonder no more. On discovering their mistake they released him.
#
# Error:  do n't know  	 Predicted: B-NEG; Actual: O
# " Ah! you do n't know Sarah 's temper or you would wonder no more. On discovering their mistake they released him.
#
# Error:  of nothing but  	 Predicted: B-NEG; Actual: O
# The last six months that she was here she would speak of nothing but his drinking and his ways. Surely we could conceal ourselves and see him do it. "
#
# Error:  about nothing but  	 Predicted: B-NEG; Actual: O
# We had a pleasant little meal together, during which Holmes would talk about nothing but violins, narrating with great exultation how he had purchased his own Stradivarius, which was worth at least five hundred guineas, at a Jew broker 's in Tottenham Court Road for fifty-five shillings. Then the door crashed to, the key turned once more, and all was silence.
#
# Error:  it not ?  	 Predicted: B-NEG; Actual: O
# In accordance with the scheme which we had formed in order to test our theories " [ " the " we " is rather fine, Watson, is it not? " ] " I went down to the Albert Dock yesterday at 6 p.m., and boarded the S.S. May Day, belonging to the Liverpool, Dublin, and London Steam Packet Company. " Danger, " is n't it?
#
# Error:  never without one  	 Predicted: B-NEG; Actual: O
# I 'm never without one or the other before me. " Why, Gregson! " said my companion as he shook hands with the Scotland Yard detective.
#
# Error:  had never darkened  	 Predicted: B-NEG; Actual: O
# But she would have forgiven me ; she would have stuck as close to me as a rope to a block if that woman had never darkened our door. I 've been taking the signals. "
#
# Error:  Ca n't you  	 Predicted: B-NEG; Actual: O
# " Ca n't you be happy for five minutes without Mary, Jim? " says she. " If I can get Gorgiano -- "
#
# Error:  Ca n't you  	 Predicted: B-NEG; Actual: O
# " Ca n't you be happy for five minutes without Mary, Jim? " says she. " If I can get Gorgiano -- "
#
# Error:  about nothing .  	 Predicted: B-NEG; Actual: O
# Day by day she grew queerer and more irritable, and we had ceaseless rows about nothing. The American struck his hands together with vexation.
#
# Error:  , no doubt  	 Predicted: B-NEG; Actual: O
# At last I saw them hire a boat and start for a row, for it was a very hot day, and they thought, no doubt, that it would be cooler on the water. Slowly she advanced, her face pale and drawn with a frightful apprehension, her eyes fixed and staring, her terrified gaze riveted upon the dark figure on the floor.
#
# Error:  are uneasy ,  	 Predicted: B-NEG; Actual: O
# Suddenly my companion 's voice broke in upon my thoughts : You are uneasy, as I understand, because your new lodger remains in his rooms and you can not see him.
#
# Error:  " No doubt  	 Predicted: B-NEG; Actual: O
# " It does seem a most preposterous way of settling a dispute. " " No doubt, sir ; but this is different.
#
# Error:  Why not write  	 Predicted: B-NEG; Actual: O
# At two o'clock yesterday afternoon a small packet, wrapped in brown paper, was handed in by the postman. Why not write?
#
# Error:  it not ?  	 Predicted: B-NEG; Actual: O
# I had a note from him this morning, in which he says : Suggestive, Watson, is it not? "
#
# Error:  absolutely nothing ?  	 Predicted: B-NEG; Actual: I-NEG
# " So I shall, Miss Cushing. Do you say nothing has come out of that room -- absolutely nothing? "
#
# Error:  from without ?  	 Predicted: B-NEG; Actual: O
# " The presumption is strongly against it. How is any news or any message to reach him from without?
#
# Error:  it not ?  	 Predicted: B-NEG; Actual: O
# One of these ears is a woman 's, small, finely formed, and pierced for an earring. It sounds plausible, does it not?
#
# Error:  it not ?  	 Predicted: B-NEG; Actual: O
# " I have found out everything! " The general sequence of events is pretty clear, is it not?
#
# Error:  it not ?  	 Predicted: B-NEG; Actual: O
# In accordance with the scheme which we had formed in order to test our theories " [ " the " we " is rather fine, Watson, is it not? " ] " I went down to the Albert Dock yesterday at 6 p.m., and boarded the S.S. May Day, belonging to the Liverpool, Dublin, and London Steam Packet Company. " Danger, " is n't it?
#
# Error:  it not ?  	 Predicted: B-NEG; Actual: O
# I can see now how she was plotting and scheming and poisoning my wife 's mind against me, but I was such a blind beetle that I could not understand it at the time. " Well, it figures out that way, does it not?
#
# Error:  you not ?  	 Predicted: B-NEG; Actual: O
# He swore like a madman and jabbed at me with an oar, for he must have seen death in my eyes. You are police, are you not?
#
# Error:  it not so  	 Predicted: B-NEG; Actual: O
# I would have spared her, perhaps, for all my madness, but she threw her arms round him, crying out to him, and calling him " Alec. " Is it not so? "
#
# Error:  -- nothing but  	 Predicted: B-NEG; Actual: O
# He had neither money nor position -- nothing but his beauty and strength and energy -- so my father forbade the match.
#
# Error:  . Not only  	 Predicted: B-NEG; Actual: O
# Not only was his body that of a giant but everything about him was grotesque, gigantic, and terrifying.
#
# Error:  and listless ,  	 Predicted: B-NEG; Actual: O
# My poor husband would sit pale and listless, listening to the endless raving upon politics and upon social questions which made up our visitor 's conversation.
#
# Error:  and listless ,  	 Predicted: B-NEG; Actual: O
# My poor husband would sit pale and listless, listening to the endless raving upon politics and upon social questions which made up our visitor 's conversation.
#
# Error:  hold nothing from  	 Predicted: B-NEG; Actual: O
# That night -- the night that I read his terror -- I put my arms round him and I implored him by his love for me and by all that he held dear to hold nothing from me, and to tell me why this huge man overshadowed him so.
#
# Error:  . No doubt  	 Predicted: B-NEG; Actual: O
# No doubt it had been prearranged in some fashion, for it was the fatal disc with the Red Circle upon it, the mandate for murder, which lay upon his palm.
#
# Error:  injuring not only  	 Predicted: B-NEG; Actual: O
# It was part of their fiendish system to punish those whom they feared or hated by injuring not only their own persons but those whom they loved, and it was the knowledge of this which hung as a terror over my poor Gennaro 's head and drove him nearly crazy with apprehension.
#
# Error:  how ruthless ,  	 Predicted: B-NEG; Actual: O
# Gorgiano had his private reasons for vengeance, but in any case we knew how ruthless, cunning, and untiring he could be.
#
# Error:  were nothing but  	 Predicted: B-NEG; Actual: O
# Finally Gennaro told me, through the paper, that he would signal to me from a certain window, but when the signals came they were nothing but warnings, which were suddenly interrupted.
#
#
#
#  False Negatives
#
# Error:  , neither the  	 Predicted: O; Actual: B-NEG
# A depleted bank account had caused me to postpone my holiday, and as to my companion, neither the country nor the sea presented the slightest attraction to him. The two forces made him lay down his gum-brush with a sigh of resignation and push back his chair.
#
# Error:  of unsolved crime  	 Predicted: O; Actual: B-NEG
# He loved to lie in the very center of five millions of people, with his filaments stretching out and running through them, responsive to every little rumour or suspicion of unsolved crime. " Well, well, Mrs. Warren, let us hear about it, then.
#
# Error:  expressed incredulity .  	 Predicted: O; Actual: B-NEG
# On my remarking that I was constantly in the habit of doing the same thing you expressed incredulity. " What has he done?
#
# Error:  still far from  	 Predicted: O; Actual: B-NEG
# But I was still far from satisfied. The scared look faded from her eyes, and her agitated features smoothed into their usual commonplace.
#
# Error:  still far from  	 Predicted: O; Actual: B-NEG
# But I was still far from satisfied. The scared look faded from her eyes, and her agitated features smoothed into their usual commonplace.
#
# Error:  an injustice .  	 Predicted: O; Actual: B-NEG
# " You do yourself an injustice. The smallest point may be the most essential.
#
# Error:  and irregular habits  	 Predicted: O; Actual: B-NEG
# Some years ago, however, when she resided at Penge, she let apartments in her house to three young medical students, whom she was obliged to get rid of on account of their noisy and irregular habits. Still, it may be as you say.
#
# Error:  and unacquainted with  	 Predicted: O; Actual: B-NEG
# The parcel was directed, then, by a man -- the printing is distinctly masculine -- of limited education and unacquainted with the town of Croydon. Then, again, the man who took the rooms spoke English well.
#
# Error:  and inexplicable horror  	 Predicted: O; Actual: B-NEG
# This brutal preliminary seemed to shadow forth some strange and inexplicable horror in the background. Ah, this is a little more possible.
#
# Error:  , discoloured ,  	 Predicted: O; Actual: B-NEG
# The other is a man 's, sun-burned, discoloured, and also pierced for an earring. The mysterious one could understand English, even if he could not print it.
#
# Error:  Sarah 's temper  	 Predicted: O; Actual: B-NEG
# " Ah! you do n't know Sarah 's temper or you would wonder no more. On discovering their mistake they released him.
#
# Error:  not unlike the  	 Predicted: O; Actual: B-NEG
# Our drive pulled up at a house which was not unlike the one which we had just quitted. There is the signal station all right.
#
# Error:  would undoubtedly have  	 Predicted: O; Actual: B-NEG
# This quarrel had put a stop to all communications for some months, so that if Browner had occasion to address a packet to Miss Sarah, he would undoubtedly have done so to her old address. That ca n't be all, Watson?
#
# Error:  exceedingly unlikely ,  	 Predicted: O; Actual: B-NEG
# " A second solution was at this stage obviously possible, and although I thought it exceedingly unlikely, I was determined to elucidate it before going further. AT -- why he is repeating it for the third time.
#
# Error:  An unsuccessful lover  	 Predicted: O; Actual: B-NEG
# An unsuccessful lover might have killed Mr. and Mrs. Browner, and the male ear might have belonged to the husband. ATTENTA three times!
#
# Error:  was impatient and  	 Predicted: O; Actual: B-NEG
# I was impatient and paced up and down the room. " I am on the trail of my life now, Mr. Holmes, " said he.
#
# Error:  had ceaseless rows  	 Predicted: O; Actual: B-NEG
# Day by day she grew queerer and more irritable, and we had ceaseless rows about nothing. The American struck his hands together with vexation.
#
# Error:  just inseparable .  	 Predicted: O; Actual: B-NEG
# Sarah avoided me now, but she and Mary were just inseparable. " Why do you think so? "
#
# Error:  parlour unexpected ,  	 Predicted: O; Actual: B-NEG
# I had come into the parlour unexpected, and as I walked in at the door I saw a light of welcome on my wife 's face. I 'll take the responsibility of arresting him now. "
# Error:  says she .  	 Predicted: O; Actual: B-NEG
# " Do n't, Jim, do n't! " says she. Gregson pushed it open.
#
# Error:  is unthinkable .  	 Predicted: O; Actual: B-NEG
# It must tend to some end, or else our universe is ruled by chance, which is unthinkable. My Gennaro!
#
# Error:  for uneasiness ,  	 Predicted: O; Actual: B-NEG
# In choosing a few typical cases which illustrate the remarkable mental qualities of my friend, Sherlock Holmes, I have endeavoured, as far as possible, to select those which presented the minimum of sensationalism, while offering a fair field for his talents. " Well, Mrs. Warren, I can not see that you have any particular cause for uneasiness, nor do I understand why I, whose time is of some value, should interfere in the matter.
#
# Error:  no more to  	 Predicted: O; Actual: I-NEG
# Your eyes flashed across to the unframed portrait of Henry Ward Beecher which stands upon the top of your books. " If not, I 'll have no more to do with you. "
#
# Error:  and neither Mr.  	 Predicted: O; Actual: B-NEG
# You felt so strongly about it that I knew you could not think of Beecher without thinking of that also. He has been there for ten days, and neither Mr. Warren, nor I, nor the girl has once set eyes upon him.
#
# Error:  -- absolutely nothing  	 Predicted: O; Actual: B-NEG
# " So I shall, Miss Cushing. Do you say nothing has come out of that room -- absolutely nothing? "
#
# Error:  be irrelevant .  	 Predicted: O; Actual: B-NEG
# Again, carbolic or rectified spirits would be the preservatives which would suggest themselves to the medical mind, certainly not rough salt. " Surely Jimmy will not break his mother 's heart " -- that appears to be irrelevant.
#
# Error:  -- unmitigated bleat  	 Predicted: O; Actual: B-NEG
# A vague thrill ran through me as I listened to my companion 's words and saw the stern gravity which had hardened his features. " Every day my heart longs -- " Bleat, Watson -- unmitigated bleat!
#
# Error:  no more of  	 Predicted: O; Actual: I-NEG
# " I am coming to be of the same opinion, Miss Cushing, " said Holmes, taking a seat beside her. " I 'll have no more of it!
#
# Error:  is neither money  	 Predicted: O; Actual: B-NEG
# What did we see first? There is neither money nor credit in it, and yet one would wish to tidy it up.
#
# Error:  in unoccupied premises  	 Predicted: O; Actual: B-NEG
# For a month he was in and out of my house, and never once did it cross my mind that harm might come of his soft, tricky ways. " He is in unoccupied premises under suspicious circumstances, " said Gregson.
#
# Error:  very unconventional English  	 Predicted: O; Actual: B-NEG
# She spoke in rapid and fluent but very unconventional English, which, for the sake of clearness, I will make grammatical.
#
# Error:  had neither money  	 Predicted: O; Actual: B-NEG
# He had neither money nor position -- nothing but his beauty and strength and energy -- so my father forbade the match.
#
# Error:  was dislike .  	 Predicted: O; Actual: B-NEG
# At first I thought that it was dislike.
#
# Error:  than dislike .  	 Predicted: O; Actual: B-NEG
# And then, gradually, I understood that it was more than dislike.
#
# Error:  never more to  	 Predicted: O; Actual: I-NEG
# He struck Gennaro senseless and fled from the house which he was never more to enter.
